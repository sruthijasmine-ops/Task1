# %%
a=int(input("a= "))
b=int(input("b= "))
c=int(input("c= "))
if a>b and a>c:
    print("a is largest")
elif b>c:
    print("b is largest")
else:
    print("c is largest")
# Out:
# a=  8
# b=  2
# c=  4
# a is largest

# %%
y=int(input("year= "))
if y%4==0:
    print("leap year")
else:
    print("not a leap year")
# Out:
# year=  2024
# leap year

# %%
a=input("character= ")
if a in ['a','e','i','o','u']:
    print("it is vowel")
else:
    print("it is consonant")
# Out:
# character=  g
# it is consonant

# %%
num=int(input("Enter any number: "))
if num%5==0 and num%11==0:
    print("num is divisible by both 5 and 11")
else:
    print("num is not divisible by both 5 and 11")
# Out:
# Enter any number:  55
# num is divisible by both 5 and 11

# %%
n=int(input("enter a number: "))
sum=0
i=1
while i<=n:
    sum=sum+i
    i=i+1
print("sum of first",n,"natural numbers is:",sum)
# Out:
# enter a number:  20
# sum of first 20 natural numbers is: 210

# %%
n=int(input("enter a number: "))
i=1
while i<=10:
    print(n,"X",i,"=",n*i)
    i=i+1
# Out:
# enter a number:  2
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# 2 X 10 = 20

# %%
n=4
i=1
while i<=n:
    s=n-i
    stars=2*i-1
    print(" "*s+"*"*stars)
    i=i+1
# Out:
#    *
#   ***
#  *****
# *******

# %%
n=5
i=1
while i<=n:
    j=1
    while j<=i:
        print(j,end="")
        j=j+1
    print()
    i=i+1
# Out:
# 1
# 12
# 123
# 1234
# 12345
